# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install seqeval
# !pip install pytorch-crf

# %%
# %cd /content/drive/MyDrive/ner-bilstm-crf
# Out:
# /content/drive/MyDrive/ner-bilstm-crf

# %%
# !python main.py
# Out:
# ----------------Loading data----------------
# 100% 337373/337373 [00:00<00:00, 793655.96it/s]
# ----------------Load successful----------------
# Total training sample: 14860
# ----------------Loading data----------------
# 100% 45356/45356 [00:00<00:00, 803915.06it/s]
# ----------------Load successful----------------
# Total valid sample: 1999
# loading pretrained embedding from:  src/resources/pretrained/embeddings_wiki_100.model
# load succesfull!
# 100% 233/233 [00:43<00:00,  5.39it/s, loss=tensor(1033.4017), epoch=0/30]
# 100% 32/32 [00:05<00:00,  5.88it/s]
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: </s> seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: <s> seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# ...
